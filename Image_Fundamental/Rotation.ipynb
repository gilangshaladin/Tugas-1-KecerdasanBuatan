# %% [markdown]
# <a href="https://colab.research.google.com/github/Hwaulat/Tugas4/blob/main/Image_Fundamental/Rotation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the necessary packages
import matplotlib.pyplot as plt
import argparse
import imutils
import cv2

# %%
def plt_imshow(title, image):
	# convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
args = {
	"image": "harimau.jpg"
}

# %%
image = cv2.imread(args["image"])
plt_imshow("Image", image)
(h, w) = image.shape[:2]
(cX, cY) = (w // 2, h // 2)
# rotate our image by 45 degrees around the center of the image
M = cv2.getRotationMatrix2D((cX, cY), 45, 1.0)
rotated = cv2.warpAffine(image, M, (w, h))
plt_imshow("Rotated by 45 Degrees", rotated)
# rotate our image by -90 degrees around the image
M = cv2.getRotationMatrix2D((cX, cY), -90, 1.0)
rotated = cv2.warpAffine(image, M, (w, h))
plt_imshow("Rotated by -90 Degrees", rotated)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 10.01.36.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 10.31.32.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 10.31.48.jpeg](data:image/jpeg;base64,...)

# %%
M = cv2.getRotationMatrix2D((10, 10), 45, 1.0)
rotated = cv2.warpAffine(image, M, (w, h))
plt_imshow("Rotated by Arbitrary Point", rotated)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 10.32.10.jpeg](data:image/jpeg;base64,...)

# %%
rotated = imutils.rotate(image, 180)
plt_imshow("Rotated by 180 Degrees", rotated)

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 10.49.16.jpeg](data:image/jpeg;base64,...)

# %%
rotated = imutils.rotate_bound(image, -33)
plt_imshow("Rotated Without Cropping", rotated)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![WhatsApp Image 2021-11-09 at 10.49.34.jpeg](data:image/jpeg;base64,...)
